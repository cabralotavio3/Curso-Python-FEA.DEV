# %% [markdown]
# # Aula 6 - Manipulação Avançada de Dados com Pandas
#
# Nessa aula, vamos aprender sobre as principais formas de **manipular dados no pandas e plotagens no matplotlib e seaborn** no Python.
#
# Faremos com o mesmo dataset da última aula.
#
# ---
#
# ### Estrutura da aula
#
# - **6.1 Fundamentos de Limpeza de Dados**
#     - 6.1.1 Tratamento de valores ausentes: `isna()`, `dropna()`, `fillna()`, `ffill()`, `bfill()`
#     - 6.1.2 Tipagem e formatação: `astype()`, `to_datetime()`, `replace()`
# - **6.2 Filtragem e Operações Booleanas e Métodos Básicos de Agregação**
#     - 6.2.1 Filtros condicionais com operadores booleanos
#     - 6.2.2 `where()` e integração vetorial com NumPy
# - **6.3 GroupBy e Agg (Abstração de Agregação)**
#     - 6.3.1 `groupby()` por um ou múltiplas colunas
#     - 6.3.2 `agg()` com métricas simultâneas
#     - 6.3.3 Diferença e Diferença Simétrica
#     - 6.3.4 Verificação de Pertencimento
# - **6.4 Concatenação e Integração de DataFrames**
#     - 6.4.1 `concat()`
#     - 6.4.2 `merge()`: inner, left, right, outer join
#     - 6.4.3 `join()` e `append()`
# - **6.5 Análise Estatística e Métodos de Análise Temporal**
#     - 6.5.1 `sum()`, `mean()`, `count()`, `std()`
#     - 6.5.2 Matriz de correlação com `corr()`
#     - 6.5.3 Interpretação estatística e multicolinearidade
#     - 6.5.4 `diff()`, `pct_change()`
# - **6.6 Vizualização**
#     - 6.6.1 `plot()`, `hist()`, `scatter()`
#     - 6.6.2 Vantagens matplotlib
#     - 6.6.3 Vantagens seaborn
#
# ---

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
cidades = pd.read_excel('PIB dos Municipios.xlsx', sheet_name='Cidades')

# %%
print(cidades.dtypes)
# Out:
# Ano                                                                                                                                                       int64
# Nome da Grande Região                                                                                                                                    object
# Código da Unidade da Federação                                                                                                                            int64
# Sigla da Unidade da Federação                                                                                                                            object
# Nome da Unidade da Federação                                                                                                                             object
# Nome do Município                                                                                                                                        object
# Nome da Mesorregião                                                                                                                                      object
# Nome da Microrregião                                                                                                                                     object
# Nome da Região Geográfica Imediata                                                                                                                       object
# Nome da Região Geográfica Intermediária                                                                                                                  object
# Hierarquia Urbana (principais categorias)                                                                                                                object
# Nome da Região Rural                                                                                                                                     object
# Região rural (segundo classificação do núcleo)                                                                                                           object
# Amazônia Legal                                                                                                                                           object
# Semiárido                                                                                                                                                object
# Valor adicionado bruto da Agropecuária, \na preços correntes\n(R$ 1.000)                                                                                float64
# Valor adicionado bruto da Indústria,\na preços correntes\n(R$ 1.000)                                                                                    float64
# Valor adicionado bruto dos Serviços,\na preços correntes \n- exceto Administração, defesa, educação e saúde públicas e seguridade social\n(R$ 1.000)    float64
# Valor adicionado bruto da Administração, defesa, educação e saúde públicas e seguridade social, \na preços correntes\n(R$ 1.000)                        float64
# Valor adicionado bruto total, \na preços correntes\n(R$ 1.000)                                                                                          float64
# Impostos, líquidos de subsídios, sobre produtos, \na preços correntes\n(R$ 1.000)                                                                       float64
# Produto Interno Bruto, \na preços correntes\n(R$ 1.000)                                                                                                 float64
# Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)                                                                                       float64
# Atividade com maior valor adicionado bruto                                                                                                               object
# Atividade com segundo maior valor adicionado bruto                                                                                                       object
# Atividade com terceiro maior valor adicionado bruto                                                                                                      object
# dtype: object

# %% [markdown]
# ## Fundamentos de Limpeza de Dados

# %% [markdown]
# ### Tratamento de Valores Ausentes

# %% [markdown]
# ### Tipagem e Formatação: `Astype()`, `to_datetime()`, `replace()`

# %% [markdown]
# #### `Astype()`

# %% [markdown]
# #### `to_datetime()`

# %%
cidades['Ano'] = pd.to_datetime(cidades['Ano'])

print(cidades.dtypes)
# Out:
# Ano                                                                                                                                                     datetime64[ns]
# Nome da Grande Região                                                                                                                                           object
# Código da Unidade da Federação                                                                                                                                   int64
# Sigla da Unidade da Federação                                                                                                                                   object
# Nome da Unidade da Federação                                                                                                                                    object
# Nome do Município                                                                                                                                               object
# Nome da Mesorregião                                                                                                                                             object
# Nome da Microrregião                                                                                                                                            object
# Nome da Região Geográfica Imediata                                                                                                                              object
# Nome da Região Geográfica Intermediária                                                                                                                         object
# Hierarquia Urbana (principais categorias)                                                                                                                       object
# Nome da Região Rural                                                                                                                                            object
# Região rural (segundo classificação do núcleo)                                                                                                                  object
# Amazônia Legal                                                                                                                                                  object
# Semiárido                                                                                                                                                       object
# Valor adicionado bruto da Agropecuária, \na preços correntes\n(R$ 1.000)                                                                                       float64
# Valor adicionado bruto da Indústria,\na preços correntes\n(R$ 1.000)                                                                                           float64
# Valor adicionado bruto dos Serviços,\na preços correntes \n- exceto Administração, defesa, educação e saúde públicas e seguridade social\n(R$ 1.000)           float64
# Valor adicionado bruto da Administração, defesa, educação e saúde públicas e seguridade social, \na preços correntes\n(R$ 1.000)                               float64
# Valor adicionado bruto total, \na preços correntes\n(R$ 1.000)                                                                                                 float64
# Impostos, líquidos de subsídios, sobre produtos, \na preços correntes\n(R$ 1.000)                                                                              float64
# Produto Interno Bruto, \na preços correntes\n(R$ 1.000)                                                                                                        float64
# Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)                                                                                              float64
# Atividade com maior valor adicionado bruto                                                                                                                      object
# Atividade com segundo maior valor adicionado bruto                                                                                                              object
# Atividade com terceiro maior valor adicionado bruto                                                                                                             object
# dtype: object

# %% [markdown]
# #### `replace()`

# %% [markdown]
# ## Filtragem e Operações Booleanas e Métodos Básicos de Agregação

# %% [markdown]
# ### Filtros Condicionais com Operadores Booleanos

# %% [markdown]
# ### `where()` e Integração com NumPy
#
# ---

# %% [markdown]
# ## GroupBy e Agg

# %% [markdown]
# ### `groupby()` Por Uma ou Múltiplas Colunas

# %% [markdown]
# ### `agg()` com Métricas Simultâneas

# %% [markdown]
# ### Diferença e Diferença Simétrica

# %% [markdown]
# ### Verificação de Pertencimento
#
# ---

# %% [markdown]
# ## Concatenação e Integração de DataFrames

# %% [markdown]
# ### `concat()`

# %% [markdown]
# ### `merge()`: inner, left, right, outer join

# %% [markdown]
# ### `join()` e `append()`
#
# ---

# %% [markdown]
# ## Análise Estatística e Métodos de Análise Temporal

# %% [markdown]
# ### `sum()`, `mean()`, `count()`, `std()`

# %% [markdown]
# ### Matriz de Correlação com `corr()`

# %% [markdown]
# ### Interpretação Estatística e Multicolinearidade

# %% [markdown]
# ### `diff()`, `pct_change()`
#
# ---

# %% [markdown]
# ## Vizualização

# %% [markdown]
# ### `plot()`, `hist()`, `scatter()`

# %% [markdown]
# ### Vantagens Matplotlib

# %% [markdown]
# ### Vantagens Seaborn
